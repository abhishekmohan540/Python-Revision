# %%
import pandas as pd
import numpy as np

# %%
dict = {"name":["Abhi","John","Jiya","Sam"], "marks":[45,89,75,65], "city":["delhi","goa","indore","Mumbai"]}

# %%
df =pd.DataFrame(dict)
df
# Out:
#    name  marks    city
# 0  Abhi     45   delhi
# 1  John     89     goa
# 2  Jiya     75  indore
# 3   Sam     65  Mumbai

# %%
df.to_csv("friends.csv")

# %%
df.to_csv("friends_with_no_index.csv", index= False)

# %%
pd.read_csv("friends_with_no_index.csv")
# Out:
#    name  marks    city
# 0  Abhi     45   delhi
# 1  John     89     goa
# 2  Jiya     75  indore
# 3   Sam     65  Mumbai

# %%
df.head()
# Out:
#    name  marks    city
# 0  Abhi     45   delhi
# 1  John     89     goa
# 2  Jiya     75  indore
# 3   Sam     65  Mumbai

# %%
df.head(2)
# Out:
#    name  marks   city
# 0  Abhi     45  delhi
# 1  John     89    goa

# %%
df.tail(2)
# Out:
#    name  marks    city
# 2  Jiya     75  indore
# 3   Sam     65  Mumbai

# %%
df.describe()
# Out:
#            marks
# count   4.000000
# mean   68.500000
# std    18.502252
# min    45.000000
# 25%    60.000000
# 50%    70.000000
# 75%    78.500000
# max    89.000000

# %%
abhi = pd.read_csv("friends.csv")

# %%
abhi
# Out:
#    Unnamed: 0  name  marks    city
# 0           0  Abhi     45   delhi
# 1           1  John     89     goa
# 2           2  Jiya     75  indore
# 3           3   Sam     65  Mumbai

# %%
abhi['name']
# Out:
# 0    Abhi
# 1    John
# 2    Jiya
# 3     Sam
# Name: name, dtype: object

# %%
abhi['marks']
# Out:
# 0    45
# 1    89
# 2    75
# 3    65
# Name: marks, dtype: int64

# %%
abhi['city']
# Out:
# 0     delhi
# 1       goa
# 2    indore
# 3    Mumbai
# Name: city, dtype: object

# %%
abhi['name'][1]
# Out:
# 'John'

# %%
## for row-> index
## for column-> column name

# %%
abhi.index= ["first","second","third","fourth"]

# %%
abhi
# Out:
#         Unnamed: 0  name  marks    city
# first            0  Abhi     45   delhi
# second           1  John     89     goa
# third            2  Jiya     75  indore
# fourth           3   Sam     65  Mumbai

# %%
abhi['Unnamed: 0']
# Out:
# first     0
# second    1
# third     2
# fourth    3
# Name: Unnamed: 0, dtype: int64

# %%
type(abhi)
# Out:
# pandas.core.frame.DataFrame

# %%
## Series

# %%
Ser=pd.Series(np.random.rand(20)
)

# %%
Ser
# Out:
# 0     0.811259
# 1     0.617556
# 2     0.049677
# 3     0.416326
# 4     0.954326
# 5     0.687631
# 6     0.767745
# 7     0.382648
# 8     0.579182
# 9     0.676552
# 10    0.564338
# 11    0.156854
# 12    0.182760
# 13    0.020659
# 14    0.650531
# 15    0.566145
# 16    0.639180
# 17    0.773705
# 18    0.418800
# 19    0.642673
# dtype: float64

# %%
type(Ser)
# Out:
# pandas.core.series.Series

# %%
newdf = pd.DataFrame(np.random.rand(100,5))

# %%
newdf
# Out:
#            0         1         2         3         4
# 0   0.023560  0.965602  0.043757  0.647205  0.759028
# 1   0.647434  0.806819  0.257785  0.370140  0.270851
# 2   0.302972  0.863904  0.599470  0.775261  0.089894
# 3   0.100296  0.489850  0.102341  0.893612  0.728200
# 4   0.432647  0.817898  0.338857  0.358575  0.821237
# ..       ...       ...       ...       ...       ...
# 95  0.339228  0.392423  0.286912  0.408832  0.269253
# 96  0.498252  0.268268  0.732332  0.991263  0.117817
# 97  0.249298  0.859274  0.301599  0.982725  0.886798
# 98  0.431708  0.219130  0.995144  0.884626  0.843862
# 99  0.508892  0.054770  0.839827  0.789240  0.887553
#
# [100 rows x 5 columns]

# %%
newdf.describe()
# Out:
#                 0           1           2           3           4
# count  100.000000  100.000000  100.000000  100.000000  100.000000
# mean     0.447123    0.574636    0.522976    0.524396    0.531342
# std      0.262635    0.292503    0.279864    0.297641    0.304185
# min      0.023560    0.001666    0.041996    0.002388    0.001229
# 25%      0.209018    0.373082    0.303700    0.267935    0.273796
# 50%      0.431985    0.647038    0.478176    0.531574    0.584960
# 75%      0.652809    0.829961    0.786630    0.782893    0.813771
# max      0.975312    0.993979    0.995144    0.998349    0.995043

# %%
newdf.dtypes
# Out:
# 0    float64
# 1    float64
# 2    float64
# 3    float64
# 4    float64
# dtype: object

# %%
newdf.shape
# Out:
# (100, 5)

# %%
newdf.index
# Out:
# RangeIndex(start=0, stop=100, step=1)

# %%
newdf.columns
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
newdf.T
# Out:
#          0         1         2         3         4         5         6   \
# 0  0.023560  0.647434  0.302972  0.100296  0.432647  0.133136  0.137846
# 1  0.965602  0.806819  0.863904  0.489850  0.817898  0.661432  0.961315
# 2  0.043757  0.257785  0.599470  0.102341  0.338857  0.917323  0.825632
# 3  0.647205  0.370140  0.775261  0.893612  0.358575  0.937798  0.576463
# 4  0.759028  0.270851  0.089894  0.728200  0.821237  0.927686  0.898403
#
#          7         8         9   ...        90        91        92        93  \
# 0  0.030229  0.243427  0.359246  ...  0.888088  0.837669  0.320391  0.071910
# 1  0.232335  0.700937  0.646064  ...  0.817240  0.121790  0.877537  0.692588
# 2  0.280370  0.746232  0.081333  ...  0.473522  0.827665  0.322628  0.912680
# 3  0.066746  0.453759  0.263298  ...  0.780777  0.480620  0.511418  0.435215
# 4  0.929713  0.095165  0.192404  ...  0.210463  0.500404  0.747714  0.028692
#
#          94        95        96        97        98        99
# ...

# %%
newdf.head()
# Out:
#           0         1         2         3         4
# 0  0.023560  0.965602  0.043757  0.647205  0.759028
# 1  0.647434  0.806819  0.257785  0.370140  0.270851
# 2  0.302972  0.863904  0.599470  0.775261  0.089894
# 3  0.100296  0.489850  0.102341  0.893612  0.728200
# 4  0.432647  0.817898  0.338857  0.358575  0.821237

# %%
newdf.columns= ["A","B","C","D","E"]

# %%
newdf.head(2)
# Out:
#           A         B         C         D         E
# 0  0.023560  0.965602  0.043757  0.647205  0.759028
# 1  0.647434  0.806819  0.257785  0.370140  0.270851

# %%
newdf.drop("E", axis=1, inplace=True)

# %%
newdf.head(3)
# Out:
#           A         B         C         D
# 0  0.023560  0.965602  0.043757  0.647205
# 1  0.647434  0.806819  0.257785  0.370140
# 2  0.302972  0.863904  0.599470  0.775261

# %%
newdf.loc[[1,2],["B","C"]]
# Out:
#           B         C
# 1  0.806819  0.257785
# 2  0.863904  0.599470

# %%
newdf.loc[[1,10],["B","C"]]
# Out:
#            B         C
# 1   0.806819  0.257785
# 10  0.819132  0.643925

# %%
newdf.loc[:,["B","C"]]
# Out:
#            B         C
# 0   0.965602  0.043757
# 1   0.806819  0.257785
# 2   0.863904  0.599470
# 3   0.489850  0.102341
# 4   0.817898  0.338857
# ..       ...       ...
# 95  0.392423  0.286912
# 96  0.268268  0.732332
# 97  0.859274  0.301599
# 98  0.219130  0.995144
# 99  0.054770  0.839827
#
# [100 rows x 2 columns]

# %%
newdf.loc[[1,2],:]
# Out:
#           A         B         C         D
# 1  0.647434  0.806819  0.257785  0.370140
# 2  0.302972  0.863904  0.599470  0.775261

# %%
newdf.loc[1:10,["B","C"]]
# Out:
#            B         C
# 1   0.806819  0.257785
# 2   0.863904  0.599470
# 3   0.489850  0.102341
# 4   0.817898  0.338857
# 5   0.661432  0.917323
# 6   0.961315  0.825632
# 7   0.232335  0.280370
# 8   0.700937  0.746232
# 9   0.646064  0.081333
# 10  0.819132  0.643925

# %%
newdf.loc[52:62,["B","C","D"]]
# Out:
#            B         C         D
# 52  0.276910  0.555520  0.616075
# 53  0.252113  0.303851  0.867629
# 54  0.058732  0.344736  0.036086
# 55  0.381060  0.870036  0.562994
# 56  0.791296  0.887210  0.093853
# 57  0.421673  0.648644  0.626382
# 58  0.959260  0.140454  0.467866
# 59  0.814379  0.457399  0.534942
# 60  0.513763  0.517050  0.077164
# 61  0.863139  0.072790  0.912608
# 62  0.355613  0.951571  0.002388

# %%
newdf.drop(0, axis=0)
# Out:
#            A         B         C         D
# 1   0.647434  0.806819  0.257785  0.370140
# 2   0.302972  0.863904  0.599470  0.775261
# 3   0.100296  0.489850  0.102341  0.893612
# 4   0.432647  0.817898  0.338857  0.358575
# 5   0.133136  0.661432  0.917323  0.937798
# ..       ...       ...       ...       ...
# 95  0.339228  0.392423  0.286912  0.408832
# 96  0.498252  0.268268  0.732332  0.991263
# 97  0.249298  0.859274  0.301599  0.982725
# 98  0.431708  0.219130  0.995144  0.884626
# 99  0.508892  0.054770  0.839827  0.789240
#
# [99 rows x 4 columns]

# %%
newdf.drop([0,2,8,10], axis=0, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[72], line 1
# ----> 1 newdf.drop([0,2,8,10], axis=0, inplace=True)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
# ...

# %%
newdf.head(10)
# Out:
#            A         B         C         D
# 1   0.647434  0.806819  0.257785  0.370140
# 3   0.100296  0.489850  0.102341  0.893612
# 4   0.432647  0.817898  0.338857  0.358575
# 5   0.133136  0.661432  0.917323  0.937798
# 6   0.137846  0.961315  0.825632  0.576463
# 7   0.030229  0.232335  0.280370  0.066746
# 9   0.359246  0.646064  0.081333  0.263298
# 11  0.188825  0.094729  0.303250  0.194443
# 12  0.317224  0.555031  0.792322  0.524532
# 13  0.494892  0.366962  0.361128  0.853837

# %%
## Now to rearrange the indexing. Use

# %%
newdf.reset_index(drop=True, inplace=True)

# %%
newdf.head(10)
# Out:
#           A         B         C         D
# 0  0.647434  0.806819  0.257785  0.370140
# 1  0.100296  0.489850  0.102341  0.893612
# 2  0.432647  0.817898  0.338857  0.358575
# 3  0.133136  0.661432  0.917323  0.937798
# 4  0.137846  0.961315  0.825632  0.576463
# 5  0.030229  0.232335  0.280370  0.066746
# 6  0.359246  0.646064  0.081333  0.263298
# 7  0.188825  0.094729  0.303250  0.194443
# 8  0.317224  0.555031  0.792322  0.524532
# 9  0.494892  0.366962  0.361128  0.853837

# %%
newdf.isnull()
# Out:
#         A      B      C      D
# 0   False  False  False  False
# 1   False  False  False  False
# 2   False  False  False  False
# 3   False  False  False  False
# 4   False  False  False  False
# ..    ...    ...    ...    ...
# 91  False  False  False  False
# 92  False  False  False  False
# 93  False  False  False  False
# 94  False  False  False  False
# 95  False  False  False  False
#
# [96 rows x 4 columns]

# %%
newdf.dropna()
# Out:
#            A         B         C         D
# 0   0.647434  0.806819  0.257785  0.370140
# 1   0.100296  0.489850  0.102341  0.893612
# 2   0.432647  0.817898  0.338857  0.358575
# 3   0.133136  0.661432  0.917323  0.937798
# 4   0.137846  0.961315  0.825632  0.576463
# ..       ...       ...       ...       ...
# 91  0.339228  0.392423  0.286912  0.408832
# 92  0.498252  0.268268  0.732332  0.991263
# 93  0.249298  0.859274  0.301599  0.982725
# 94  0.431708  0.219130  0.995144  0.884626
# 95  0.508892  0.054770  0.839827  0.789240
#
# [96 rows x 4 columns]

# %%
newdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96 entries, 0 to 95
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       96 non-null     float64
#  1   B       96 non-null     float64
#  2   C       96 non-null     float64
#  3   D       96 non-null     float64
# dtypes: float64(4)
# memory usage: 3.1 KB

# %%
newdf["A"].value_counts()
# Out:
# A
# 0.647434    1
# 0.100296    1
# 0.358122    1
# 0.297968    1
# 0.169090    1
#            ..
# 0.861228    1
# 0.583556    1
# 0.599480    1
# 0.612210    1
# 0.508892    1
# Name: count, Length: 96, dtype: int64

# %%
newdf.describe()
# Out:
#                A          B          C          D
# count  96.000000  96.000000  96.000000  96.000000
# mean    0.458257   0.563688   0.523585   0.526212
# std     0.261306   0.292835   0.280114   0.298402
# min     0.030229   0.001666   0.041996   0.002388
# 25%     0.233882   0.370589   0.303700   0.267935
# 50%     0.434279   0.613268   0.465461   0.531574
# 75%     0.660458   0.819696   0.799322   0.792864
# max     0.975312   0.993979   0.995144   0.998349

# %%
newdf.mean()
# Out:
# A    0.458257
# B    0.563688
# C    0.523585
# D    0.526212
# dtype: float64

# %%
newdf.max()
# Out:
# A    0.975312
# B    0.993979
# C    0.995144
# D    0.998349
# dtype: float64

# %%
newdf.median()
# Out:
# A    0.434279
# B    0.613268
# C    0.465461
# D    0.531574
# dtype: float64

# %%
newdf.corr()
# Out:
#           A         B         C         D
# A  1.000000 -0.110778  0.005061 -0.006791
# B -0.110778  1.000000 -0.029243  0.096833
# C  0.005061 -0.029243  1.000000  0.014624
# D -0.006791  0.096833  0.014624  1.000000
